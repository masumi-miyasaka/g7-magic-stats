# %% [markdown]
# # 消えたGDP：G7の「統計の魔法」をデータで暴く
#
# ## 1. はじめに：私たちの実感は、なぜ統計とズレるのか？
# 「物価高で生活が苦しい」という実感。一方で、発表されるインフレ率は2%台。
# この「10%近い体感インフレ」と「2%の公式発表」の間の空白には、何が隠されているのか。
# 情報科学を学ぶ学生の視点から、嘘をつけない「税収」というキャッシュフローを軸に、G7のデータを分析する。日本のインフレ率、名目賃金成長率、実質賃金上昇率と体感インフレ率がどう乖離しているのか？それをわかりやすく図示する。

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import wbgapi as wd

plt.rcParams['font.size'] = 12
plt.style.use('ggplot')

# %% [markdown]
# ## 2. データの調達：世界標準の「証言者」を呼ぶ
# 世界銀行（World Bank）のAPIを使い、G7各国の以下の指標を過去10年分取得します。
# - インフレ率（CPI）
# - 名目GDP（USDベース）
# - 税収（GDP比率）
#
# インフレ率が間違っているのではないかという指摘。政府の税収からインフレ率を逆算する方法とその妥当性の検証。税収とインフレ率の主要先進国の推移から日本の異常性を示す。

# %% [markdown]
# ##　3．　私たちの体感インフレ率は果たして間違っていたのか？
# 税収とインフレ率の関係から想定される本来あるべきインフレ率を逆算する。それをもとに実質賃金の推移を再計算する。どれだけの購買力が毀損したのか？私たちの生活はどれくらい厳しくなっていたのか？

# %% [markdown]
# 経済活動においては全ての主体が損をするということはない。それなら、このインフレで誰が儲かったのか？富の移管の考察をする。想定通りならば、政府が儲かったと結論づける他ないはずだ。少なくとも消費者ではない。必要な分析の方法を考える必要がある。

# %% [markdown]
# ## 4. invert, always invert
# 我が身を守るために何をするべきか？資産防衛について考察する。簡単でいいだろう。

# %% [markdown]
# ## 5. 免責事項
# 詳細については考える必要がある。
